# %% [markdown]
# ## **REGULAR EXPRESSIONS / CLASS WORK-2**

# %% [markdown]
# **IMPORTING PACKAGES AND READING FILE**

# %%
#importing the pandas library
import pandas as pd

# %%
#storing the file location in file varaible
file=(r"C:\Users\HP\Downloads\un-general-debates-blueprint.csv")

# %%
#to read the csv file
df=pd.read_csv(file)

# %%
#to get first 20 rows of the dataset
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# ...

# %% [markdown]
# **DISPLAYING COLUMNS IN DATAFRAME**

# %%
#to find the column names
df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %% [markdown]
# **DATA TYPES OF EACH COLUMN**

# %%
#to find the datatypes of the columns
df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %% [markdown]
# **INFO METHOD**

# %%
#to get the information about columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %% [markdown]
# **DESCIPTIVE STATISTICS**

# %%
##finding the statistical analysis on the dataset
df.describe()
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %% [markdown]
# **LENGTH FUNCTION**

# %%
#storing the length of string of text column in length column
df['length']=df['text'].str.len()

# %% [markdown]
# **DESCRIBE METHOD**

# %%
#finding the statistical analysis on the dataset
df.describe()
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %%
#pulls out the objects dtypes attributes and shows their count, frequency, max.
df.describe(include='O')
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %% [markdown]
# **CHECKING FOR NULL VALUES**

# %%
#checking the null values in dataset
df.isna().sum()
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# length             0
# dtype: int64

# %%
#replacing the null values with "unknown"
df['speaker'].fillna('unknown',inplace=True)

# %%
#replacing the null values with "unknown"
df['position'].fillna('unknown',inplace=True)

# %%
#checking the null values in dataset.
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %% [markdown]
# **CONVERTING TO UPPERCASE WITH KEYWORD**

# %%
df['speaker']=df['speaker'].str.upper()# converting the speaker column to upper case
df['position']=df['speaker'].str.upper()# converting the position column to upper case
df['text']=df['text'].str.upper()# converting the text column to upper case

# %% [markdown]
# **PLOTTING**

# %%
#plot
df['length'].plot()
# Out:
# <Axes: >

# %% [markdown]
# **BOXPLOT**

# %%
#plotting the box plot
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %% [markdown]
# **HISTOGRAM**

# %%
#plotting the histogram
df['length'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns #importing the seaborn library

# %% [markdown]
# **BOXPLOT**

# %%
#plotting the box plot
import seaborn as sns
import matplotlib.pyplot as plt

where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x='country', y="length", kind='box')
g.fig.set_size_inches(10, 8)

# Adding legend
plt.legend(title='Country', labels=['USA', 'France', 'UK', 'China', 'Russia'])
plt.show()

# %% [markdown]
# **REGULAR EXPRESSIONS**
#
# Regular expression (regex or regexp) is a sequence of characters that forms a search pattern. It is a powerful tool for string manipulation and searching. The re module in Python provides support for regular expressions.

# %%
import regex as re #importing regex module.
def tokenize(text):
  return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %%
#storing the string in testtext variable
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# **STOPWORDS**

# %%
#importing the nltk module
import nltk

# %%
#printing the stopwords using nltk module
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'in', "didn't", 'having', 'other', 'his', "weren't", 'themselves', 'that', 'myself', 'doesn', 'on', 'mustn', "you'd", 'itself', 'a', 'being', 'when', "you've", 'an', "should've", 'more', "isn't", "you'll", 'through', 'while', 'over', 'of', "don't", "wasn't", 'her', 'such', 'then', 'just', 'aren', 'both', 'haven', 'the', "haven't", 'at', 'shouldn', 'isn', "wouldn't", 're', 'there', 'about', 'theirs', 'their', 'they', 'below', 'can', 'whom', 'were', 'because', 'ourselves', 'm', 'against', 'very', 'into', 'yourselves', 'this', 'as', "hadn't", 'd', 'had', 'them', "she's", 'hadn', 'should', 'up', 'been', 'mightn', 'hers', 'did', "won't", 'by', 'herself', 'than', 'each', 'own', 'those', "doesn't", 'with', 'are', 've', 'these', 'again', 'during', 'ain', "hasn't", 't', 's', 'who', 'any', 'o', 'some', 'needn', 'he', "shouldn't", 'your', 'i', "aren't", 'most', 'not', 'wouldn', 'we', 'for', 'down', "that'll", 'am', 'don', 'has', 'here', 'above', 'weren', 'will', 'y', 'after', 'ma', 'wasn', 'wa
# ...

# %% [markdown]
# **TOKENIZATION**

# %%
#creating the function for removing stop words
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# %%
#calling method by giving tetstokens as input
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %% [markdown]
# **TEXT PROCESSING PIPELINE**

# %%
#creating the pipeline
pipeline = [str.lower, tokenize, remove_stop]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %%
#running the pipeline
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
#counting the tokens
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
#                                position  \
# 7502  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503               MR. TOMISLAV NIKOLIĆ
# 7504                         JACOB ZUMA
# 7505             MR. EDGAR CHAGWA LUNGU
# 7506                      ROBERT MUGABE
#
#                                                    text  length  \
# 7502  ON BEHALF OF THE PEOPLE AND THE GOVERNMENT OF ...   10568
# 7503  \nSEVENTY YEARS HAVE PASSED SINCE THE ESTABLIS...   25430
# ...

# %% [markdown]
# **COUNTING WORDS**
#
# A Counter is a data type in the collections module. It is a dict subclass that stores counts for hashable objects.

# %%
#importing the counter package from collections package
from collections import Counter
tokens = tokenize("She likes my cats and my cats like my sofa.")
testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %%
#adding new data to current count
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# **DISPLAYING KEY VALUES**

# %%
#counting the words
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('nations', 124508), ('united', 120763), ('international', 117223), ('world', 89421), ('countries', 85734)]

# %% [markdown]
# **CREATING DATAFRAME AND FILTERING ENTRIES**

# %%
#put the word frequency in  owndataframe for analysis
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %% [markdown]
# **SORTING**

# %%
#sorting and displaying words and its frequencies
freq_df = freq_df.sort_values('freq', ascending=False) # sorting according to frequency
freq_df.head(10)
# Out:
#                  freq
# token
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# peace           72625
# development     62632
# states          59713
# people          59338
# security        58425

# %% [markdown]
# **DESCRIPTIVE STATISTICS**

# %%
#statistical analysis of frq_df dataframe
freq_df.describe()
# Out:
#                 freq
# count   68302.000000
# mean      162.686276
# std      1544.080072
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%        15.000000
# max    124508.000000

# %% [markdown]
# **BARPLOT**
#
# Bar plots are commonly used to show the distribution of a categorical variable or to compare the values of different categories.

# %%
#plotting the bar chat
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# **WORDCLOUD**
#
# Word cloud is one of the most powerful and straightforward visualization methods when it comes to text data. The size of words are dependent on the occurrence frequency

# %%
 #imporitng word cloud 
from wordcloud import WordCloud
from matplotlib import pyplot as plt
wc = WordCloud(background_color='black', width = 600, height=600, max_words=100, margin=2)
text = df.query("year==2015 and country=='USA'")['text'].values[0]
plt.figure(figsize=(14, 7)) 
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc = WordCloud(background_color='white', width = 600, height=600, max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
