# %%
name="kanth"
print(name)
# Out:
# kanth

# %%
print(name[1:3])
# Out:
# an

# %%
print(name.upper())
print(name.lower())
print(name.replace("t","T"))
# Out:
# KANTH
# kanth
# kanTh

# %%
frst='laxmi'
fullName=frst+name
print(fullName)
# Out:
# laxmikanth

# %%
for i in fullName:
  print(i)
# Out:
# l
# a
# x
# m
# i
# k
# a
# n
# t
# h

# %%
for i in range (0,len(fullName)):
  print(fullName[i])
# Out:
# l
# a
# x
# m
# i
# k
# a
# n
# t
# h

# %%
myString="1 2 3 4 5"
print(myString.split())
# Out:
# ['1', '2', '3', '4', '5']

# %%
myString="1/2/3/4/5"
print(myString.split("/"))
# Out:
# ['1', '2', '3', '4', '5']

# %%
myString="1@2@3@4@5"
print(myString.split("@"))
# Out:
# ['1', '2', '3', '4', '5']

# %%
myString="1@2@3/4/5"
print(myString.split("/" and "@"))
# Out:
# ['1', '2', '3/4/5']

# %% [markdown]
# here the special characters are called **DELIMETER**

# %%
print(fullName.find("kanth"))
# Out:
# 5

# %%
print(fullName.startswith("kanth"))
# Out:
# False

# %%
clas="    python"
print(clas.lstrip())
# Out:
# python

# %%
clas="  python"
print(clas.lstrip("p"))
# Out:
#   python

# %%
clas="  python   "
print(clas.strip())
# Out:
# python

# %%
alnum="python123"

# %%
print(alnum.isalpha())
print(alnum.isalnum())
print(alnum.isdigit())
# Out:
# False
# True
# False
