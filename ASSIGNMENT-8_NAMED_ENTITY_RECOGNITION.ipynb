# %% [markdown]
# **CLASSWORK- / NAMED ENTITY RECOGNITION**

# %% [markdown]
# **SpaCy**
#
# SpaCy is a powerful library for linguistic data processing. It providesa pipeline of processing components: a tokenizer, a part-of-speechtagger, a dependency parser and a named-entity recognizer.

# %% [markdown]
# **IMPORTING REQUIRED LIBRARIES**

# %%
# !python -m spacy download en_core_web_lg
# !python -m spacy download de_core_news_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ---------------------------------------- 0.0/587.7 MB ? eta -:--:--
#      -------------------------------------- 0.0/587.7 MB 682.7 kB/s eta 0:14:21
#      -------------------------------------- 0.0/587.7 MB 393.8 kB/s eta 0:24:53
#      -------------------------------------- 0.1/587.7 MB 573.4 kB/s eta 0:17:05
#      ---------------------------------------- 0.2/587.7 MB 1.1 MB/s eta 0:08:57
#      ---------------------------------------- 0.2/587.7 MB 1.2 MB/s eta 0:08:27
#      ---------------------------------------- 0.9/587.7 MB 3.1 MB/s eta 0:03:12
#      ---------------------------------------- 2.2/587.7 MB 6.7 MB/s eta 0:01:27
#      --------------------------------------- 4.7/587.7 MB 12.5 MB/s eta 0:00:47
#      --------------------------------------- 6.7/587.7 MB 16.0 MB/s eta 0:00:37
#       -------------------------------------- 7.9/587.7 MB 17.3 MB/s eta 0:00:34
#       -------------------------------------- 7.9/587.7 MB 17.3 MB/s eta 0:00:34
#       -------------------------------------- 9.6/587.7 MB 17.6 MB/s eta 0:00:33
#       ------------------------------------- 14.8/587.7 MB 46.9 MB/s eta 0:00:13
#      - ------------------------------------ 17.1/587.7 MB 54.4 MB/s eta 0:00:11
#      - ------------------------------------ 17.4/587.7 MB 50.4 MB/s eta 0:00:12
#      - ------------------------------------ 21.5/587.7 MB 59.5 MB/s eta 0:00:10
#      - ------------------------------------ 25.7/587.7 MB 65.6 MB/s eta 0:00:09
#      - ------------------------------------ 29.0/587.7 MB 81.8 MB/s eta 0:00:07
#      -- ----------------------------------- 31.3/587.7 MB 72.6 MB/s eta 0:00:08
#      -- ----------------------------------- 32.7/587.7 MB 72.6 MB/s eta 0:00:08
#      -- ----------------------------------- 33.0/587.7 MB 50.4 MB/s eta 0:00:12
#      -- ----------------------------------- 35.4/587.7 MB 43.5 MB/s eta 0:00:13
#      -- ----------------------------------- 39.2/587.7 MB 46.7 MB/s eta 0:00:12
#      -- ----------------------------------- 42.4/587.7 MB 50.4 MB/s eta 0:00:11
#      -- ----------------------------------- 44.8/587.7 MB 72.6 MB/s eta 0:00:08
#      --- ---------------------------------- 47.7/587.7 MB 65.6 MB/s eta 0:00:09
#      --- ---------------------------------- 50.0/587.7 MB 65.2 MB/s eta 0:00:09
#      --- ---------------------------------- 52.6/587.7 MB 59.5 MB/s eta 0:00:09
#      --- ---------------------------------- 55.2/587.7 MB 59.8 MB/s eta 0:00:09
#      --- ---------------------------------- 58.5/587.7 MB 59.5 MB/s eta 0:00:09
#      --- ---------------------------------- 61.6/587.7 MB 59.5 MB/s eta 0:00:09
#      ---- --------------------------------- 63.4/587.7 MB 59.5 MB/s eta 0:00:09
#      ---- --------------------------------- 67.1/587.7 MB 65.6 MB/s eta 0:00:08
# Installing collected packages: de-core-news-sm
# Successfully installed de-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
# Load the english language model
nlp = spacy.load("en_core_web_lg")
# Load the German language model
nlp = spacy.load("de_core_news_sm")

# %% [markdown]
# **TRYING ON SAMPLE TEXT**

# %%
text = "This time india is going to win the world cup."
doc = nlp(text)
for token in doc:
  print(token, end=" | ")
# Out:
# This | time | india | is | going | to | win | the | world | cup | . |

# %%
import pandas as pd
def display_nlp(doc, include_punct=False):
  """Generate data frame for visualization of spaCy tokens."""
  rows = []
  for i, t in enumerate(doc):
    if not t.is_punct or include_punct:
      row = {'token': i, 'text': t.text, 'lemma_': t.lemma_,'is_stop': t.is_stop, 'is_alpha': t.is_alpha,'pos_': t.pos_, 'dep_': t.dep_,'ent_type_': t.ent_type_, 'ent_iob_': t.ent_iob_}
      rows.append(row)
  df = pd.DataFrame(rows).set_index('token')
  df.index.name = None
  return df
display_nlp(doc)
# Out:
#     text lemma_  is_stop  is_alpha   pos_  dep_ ent_type_ ent_iob_
# 0   This   This    False      True  PROPN    sb      MISC        B
# 1   time   time    False      True      X  ROOT      MISC        I
# 2  india  india    False      True      X    mo      MISC        I
# 3     is     --    False      True      X    uc      MISC        I
# 4  going  going    False      True      X    uc      MISC        I
# 5     to     to    False      True      X    uc      MISC        I
# 6    win    win    False      True      X   pnc      MISC        I
# 7    the    The    False      True  PROPN   pnc      MISC        I
# 8  world  World    False      True  PROPN   pnc      MISC        I
# 9    cup    cup    False      True  PROPN    uc      MISC        I

# %% [markdown]
# **REMOVING STOP WORDS USING SPACY**

# %%
text = "India is the best cricket team in the world"
doc = nlp(text)

# %%
non_stop = [t for t in doc if not t.is_stop and not t.is_punct]
print(non_stop)
# Out:
# [India, is, the, best, cricket, team, the, world]

# %% [markdown]
# **FINDING NOUNS USING SPACY**

# %%
text = "Kohli is the king of the cricket world"
doc = nlp(text)

# %%
nouns = [t for t in doc if t.pos_ in ['NOUN', 'PROPN']]
print(nouns)
# Out:
# [Kohli, the, the, cricket, world]

# %% [markdown]
# **NAMED ENTITY RECOGNITION**

# %%
text = "Kohli is the king of the cricket world."
doc = nlp(text)

# %%
for ent in doc.ents:
  print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (Kohli is the king of the, MISC)

# %%
from spacy import displacy
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kohli is the king of the
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  cricket world.</div></span>

# %% [markdown]
# **Harder one:**

# %%
text = "James O'Neill, chairman of World Cargo Inc, lives in SanFrancisco."
doc = nlp(text)

# %%
for ent in doc.ents:
  print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (James O'Neill, PER) (chairman of World Cargo Inc, MISC) (SanFrancisco, MISC)

# %% [markdown]
#  **VISUALIZE NERS**

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James O'Neill
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chairman of World Cargo Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , lives in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SanFrancisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .</div></span>

# %% [markdown]
# **TRYING WITH REAL DATASET**

# %%
from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
  res = requests.get(url)
  html = res.text
  soup = BeautifulSoup(html, 'html.parser')
  for script in soup(["script", "style", 'aside']):
    script.extract()
  return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string('https://blog.google/technology/health/google-ai-health-information/')
article=nlp(ny_bb)
len(article.ents)
# Out:
# 147

# %%
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> 3 ways
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  is connecting people to helpful health information Skip to main content         The Keyword            How we’re using AI to connect people to health information    Share
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter Facebook LinkedIn Mail Copy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  link                Latest stories                            Product updates                    Product updates
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Android
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chrome &amp; Play
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# Android                                                       Chrome                                                       Chromebooks                                                       Google Play                                                       Wear OS by Google                                                 Devices &amp; Services                                Chromecast                                                       Fitbit                                                       Google Nest                                                       Pixel                                                 Explore &amp; Get Answers                                Gemini                                                       Google Assistant                                                       Maps                                                       News                                                       Search                                                       Shopping                                                 Connect &amp; Communicate                                Photos                                                       Translate                                                       Registry                                                 In The Cloud                                Docs,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sheets and Slides
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# Gmail                                                       Google Cloud                                                       Meet                                                       More on the Cloud Blog                                               See all product updates                  Android,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chrome &amp; Play                                Android                                                             Chrome                                                             Chromebooks                                                             Google Play                                                             Wear
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  OS by
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google                                                     Devices &amp; Services
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# Chromecast                                                             Fitbit                                                             Google Nest                                                             Pixel                                                     Explore &amp; Get Answers                                Gemini                                                             Google Assistant                                                             Maps                                                             News                                                             Search                                                             Shopping                                                     Connect &amp; Communicate                                Photos                                                             Translate                                                             Registry                                                     In
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Cloud                                Docs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sheets and Slides                                                             Gmail                                                             Google Cloud                                                             Meet                                                             More on the
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Cloud Blog                                                     See all product updates                        Company news                    Company news
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Outreach &amp; initiatives                                Diversity and inclusion                                                       Education
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# Google.org                                                       Grow with Google                                                       Sustainability                                                        See all                              Technology                                AI                                                       Developers                                                       Families                                                       Next billion users
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Safety and security

# %%
from collections import Counter
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('Google', 3),
#  ('SVP', 3),
#  ('English', 3),
#  ('Twitter Facebook LinkedIn Mail Copy', 2),
#  ('Android', 2)]

# %% [markdown]
# **POPULAR NER TYPES:**

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'MISC': 62, 'ORG': 30, 'PER': 30, 'LOC': 25})

# %%
sentences = [x for x in article.sents]
print(sentences[9])
# Out:
# link                Latest stories                            Product updates                    Product updates                Android, Chrome & Play

# %% [markdown]
# **NER tags**

# %%
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\spacy\displacy\__init__.py:213: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> </div></span>

# %% [markdown]
# **TYPES OF WORDS IN THE SENTENCE**

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y for y in nlp(str(sentences[0]))
if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [(' ', 'SPACE', ' ')]

# %% [markdown]
# **SENTENCE DEPENDENCY TREE**

# %%
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True,
options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="de" id="ce7ac1c7a93a49eface9730893e050f7-0" class="displacy" width="170" height="137.0" direction="ltr" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
# </svg></span>

# %% [markdown]
# **2 CONVERT URL TO TEXT AND COUNT ENTITIES**

# %%
# Convert the content of a given URL into text and count the identified entities

from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string('https://www.tvtoday.de/tv-programm/')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 1250

# %% [markdown]
# VISUALIZE ENTITIES IN TEXT

# %%
# Render a visualization of the identified entities in the extracted article text.

displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> Das Fernsehprogramm von heute bei
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV TODAY
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  .                         Abo bestellen
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV-Programm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV-Programm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  von heute
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV-Programm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  von morgen
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV-Programm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  von gestern
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV-Tipps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  heute                                                                                  TV-Guide
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Classic                                                                                  TV-Programm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  nach
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zeit                                                                                  TV-Programm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  nach Sparten
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV-Programm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  nach
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sendern
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#                                                                                   Filme                                                                                  Sport                                          Fußball:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bundesli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ...
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eintracht Frankfu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ... Ein Leben in zehn... Mehr als 50 Filme...                     Jetzt im
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# 20:15 im
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# 22:00 im
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# TV-Highlights                                                              Fußball im
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# Erotik im
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV                                                                                  TV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Aktuell                                                                                  TV-Premieren                                                                                  Tatort im
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TV                                          Polizeiruf 110
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# :
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ... Im deutsch-polnis...
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jungle Cruise Riesenschlangen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,... &quot;
# <mark class="entity" style="background: #ddd;

# %% [markdown]
# COUNT ENTITY LABELS

# %%
# Count the occurrence of each entity label in the extracted article text.

from collections import Counter

labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'MISC': 528, 'LOC': 325, 'ORG': 260, 'PER': 137})

# %% [markdown]
# COUNT MOST COMMON ENTITIES

# %%
# Count the 25 most common entities in the extracted article text.

items = [x.text for x in article.ents]
Counter(items).most_common(25)
# Out:
# [('USA', 116),
#  ('D', 84),
#  ('ReportDokusoap', 14),
#  ('ZDF', 11),
#  ('Kan', 11),
#  ('ProSieben', 10),
#  ('VOX', 9),
#  ('VisierKrimiserie', 9),
#  ('ARTE', 7),
#  ('ZDFneo', 7),
#  ('F', 7),
#  ('GrenzeDoku', 7),
#  ('VersicherungsdetektiveDokusoap', 7),
#  ('TV-Programm', 6),
#  ('RTLZWEI', 6),
#  ('HundeflüstererCoachingdoku', 6),
#  ('RTLup', 6),
#  ('Italiens', 6),
#  ('Patrol New Zealand', 6),
#  ('GerichtsmedizinDoku', 6),
#  ('ONE', 5),
#  ('D 2024Mit', 5),
#  ('TELE', 5),
#  ('HobbyKrimiserie', 5),
#  ('NITRO', 5)]

# %% [markdown]
# PRINT SPECIFIC SENTENCE

# %%
# Print the 4th sentence from the extracted article text.

sentences = [x for x in article.sents]
print(sentences[3])
# Out:
# Bundesli...

# %% [markdown]
# VISUALIZE ENTITIES IN SPECIFIC SENTENCE

# %%
# Render a visualization of the identified entities in the 4th sentence of the extracted article text.

displacy.render(nlp(str(sentences[3])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bundesli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ...</div></span>

# %% [markdown]
# EXTRACT WORDS WITH PARTS OF SPEECH AND LEMMAS

# %%
# Extract words along with their parts of speech and lemmas from the 4th sentence of the extracted article text, excluding stop words and punctuation.

[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[3])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Bundesli', 'PROPN', 'Bundesli')]

# %% [markdown]
# VISUALIZE DEPENDENCY PARSING

# %%
# Render a visualization of the dependency parsing for the 4th sentence of the extracted article text with adjusted distance between words.

displacy.render(nlp(str(sentences[1])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="de" id="7495b6df390649c991b5fb9ec9002b26-0" class="displacy" width="1010" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Das</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Fernsehprogramm</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">von</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">heute</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">bei</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">TV</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">TODAY .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">                        </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7495b6df390649c991b5fb9ec9002b26-0-0" stroke-width="2px" d="M70,182.0 C70,122.0 160.0,122.0 160.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7495b6df390649c991b5fb9ec9002b26-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7495b6df390649c991b5fb9ec9002b26-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7495b6df390649c991b5fb9ec9002b26-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mnr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M280.0,184.0 L288.0,172.0 272.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7495b6df390649c991b5fb9ec9002b26-0-2" stroke-width="2px" d="M310,182.0 C310,122.0 400.0,122.0 400.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7495b6df390649c991b5fb9ec9002b26-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,184.0 L408.0,172.0 392.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7495b6df390649c991b5fb9ec9002b26-0-3" stroke-width="2px" d="M190,182.0 C190,62.0 525.0,62.0 525.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7495b6df390649c991b5fb9ec9002b26-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mnr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,184.0 L533.0,172.0 517.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7495b6df390649c991b5fb9ec9002b26-0-4" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7495b6df390649c991b5fb9ec9002b26-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M640.0,184.0 L648.0,172.0 632.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7495b6df390649c991b5fb9ec9002b26-0-5" stroke-width="2px" d="M190,182.0 C190,2.0 770.0,2.0 770.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7495b6df390649c991b5fb9ec9002b26-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770.0,184.0 L778.0,172.0 762.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7495b6df390649c991b5fb9ec9002b26-0-6" stroke-width="2px" d="M790,182.0 C790,122.0 880.0,122.0 880.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7495b6df390649c991b5fb9ec9002b26-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M880.0,184.0 L888.0,172.0 872.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# **3 CONVERT URL TO TEXT AND COUNT ENTITIES**

# %%
# Convert the content of a given URL into text and count the identified entities.

from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string('https://www.bbc.com/zhongwen/simp')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 40
